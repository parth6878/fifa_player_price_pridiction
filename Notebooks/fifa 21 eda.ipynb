# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\eda\data\fifa21 raw data v2.csv")
df
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_9564\97451955.py:1: DtypeWarning: Columns (0: Hits) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\eda\data\fifa21 raw data v2.csv")
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df.drop(["photoUrl","playerUrl","LongName","Positions","Loan Date End","BOV"],axis = 1, inplace = True)
df.rename({"↓OVA":"OVA"},axis=1,inplace= True)

# %%
for col in df.columns:
    print(col)
    print(df[col].isna().sum())
    print('-'*50)
# Out:
# ID
# 0
# --------------------------------------------------
# Name
# 0
# --------------------------------------------------
# Nationality
# 0
# --------------------------------------------------
# Age
# 0
# --------------------------------------------------
# OVA
# 0
# --------------------------------------------------
# POT
# 0
# --------------------------------------------------
# Club
# 0
# --------------------------------------------------
# Contract
# 0
# --------------------------------------------------
# Height
# 0
# --------------------------------------------------
# Weight
# 0
# --------------------------------------------------
# Preferred Foot
# 0
# --------------------------------------------------
# Best Position
# 0
# --------------------------------------------------
# Joined
# 0
# --------------------------------------------------
# Value
# 0
# --------------------------------------------------
# Wage
# 0
# --------------------------------------------------
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Nationality', 'Age', 'OVA', 'POT', 'Club', 'Contract',
#        'Height', 'Weight', 'Preferred Foot', 'Best Position', 'Joined',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 71 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  str
#  2   Nationality       18979 non-null  str
#  3   Age               18979 non-null  int64
#  4   OVA               18979 non-null  int64
#  5   POT               18979 non-null  int64
#  6   Club              18979 non-null  str
#  7   Contract          18979 non-null  str
#  8   Height            18979 non-null  str
#  9   Weight            18979 non-null  str
#  10  Preferred Foot    18979 non-null  str
#  11  Best Position     18979 non-null  str
#  12  Joined            18979 non-null  str
#  13  Value             18979 non-null  str
#  14  Wage              18979 non-null  str
#  15  Release Clause    18979 non-null  str
#  16  Attacking         18979 non-null  int64
# ...

# %%
for col in df.columns.to_list():
    print(col)
    print(df[col].unique())
# Out:
# ID
# [158023  20801 200389 ... 252757 243790 252520]
# Name
# <StringArray>
# [         'L. Messi', 'Cristiano Ronaldo',          'J. Oblak',
#       'K. De Bruyne',         'Neymar Jr',    'R. Lewandowski',
#           'M. Salah',           'Alisson',         'K. Mbappé',
#      'M. ter Stegen',
#  ...
#           'Song Yue',      'Wang Huapeng',         'M. Flores',
#     'Zhang Mengxuan',       'V. Da Silva',            'Xia Ao',
#           'B. Hough',       'R. McKinley',      'Wang Zhen'ao',
#          'Zhou Xiao']
# Length: 17920, dtype: str
# Nationality
# <StringArray>
# [  'Argentina',    'Portugal',    'Slovenia',     'Belgium',      'Brazil',
#       'Poland',       'Egypt',      'France',     'Germany', 'Netherlands',
#  ...
#        'Niger',   'Korea DPR',    'Barbados',       'Macau', 'South Sudan',
#    'Singapore',   'Hong Kong',   'Nicaragua',    'Malaysia',   'Indonesia']
# Length: 164, dtype: str
# Age
# ...

# %% [markdown]
# #### converting height and weight column to int

# %%
df.Weight.unique()
# Out:
# <StringArray>
# [  '72kg',   '83kg',   '87kg',   '70kg',   '68kg',   '80kg',   '71kg',
#    '91kg',   '73kg',   '85kg',   '92kg',   '69kg',   '84kg',   '96kg',
#    '81kg',   '82kg',   '75kg',   '86kg',   '89kg',   '74kg',   '76kg',
#    '64kg',   '78kg',   '90kg',   '66kg',   '60kg',   '94kg',   '79kg',
#    '67kg',   '65kg',   '59kg',   '61kg',   '93kg',   '88kg',   '97kg',
#    '77kg',   '62kg',   '63kg',   '95kg',  '100kg',   '58kg', '183lbs',
#  '179lbs', '172lbs', '196lbs', '176lbs', '185lbs', '170lbs', '203lbs',
#  '168lbs', '161lbs', '146lbs', '130lbs', '190lbs', '174lbs', '148lbs',
#  '165lbs', '159lbs', '192lbs', '181lbs', '139lbs', '154lbs', '157lbs',
#  '163lbs',   '98kg',  '103kg',   '99kg',  '102kg',   '56kg',  '101kg',
#    '57kg',   '55kg',  '104kg',  '107kg',  '110kg',   '53kg',   '50kg',
#    '54kg',   '52kg']
# Length: 79, dtype: str

# %%
df.Height.unique()
# Out:
# <StringArray>
# ['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm', '178cm',
#  '193cm', '185cm', '199cm', '173cm', '168cm', '176cm', '177cm', '183cm',
#  '180cm', '189cm', '179cm', '195cm', '172cm', '182cm', '186cm', '192cm',
#  '165cm', '194cm', '167cm', '196cm', '163cm', '190cm', '174cm', '169cm',
#  '171cm', '197cm', '200cm', '166cm',  '6'2"', '164cm', '198cm',  '6'3"',
#   '6'5"', '5'11"',  '6'4"',  '6'1"',  '6'0"', '5'10"',  '5'9"',  '5'6"',
#   '5'7"',  '5'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#  '157cm', '156cm', '202cm', '159cm', '206cm', '155cm']
# Length: 62, dtype: str

# %%
def clean_height(x):
    try:
        return int((int(x[0]) * 30.48) + (int(x[1]) * 2.54))
    except:
        return int(x[0])

# %%
df["Height"]=df["Height"].apply(lambda x: x.split('c')[0])
df["Height"]=df["Height"].apply(lambda x: x.rstrip("\"")).apply(lambda x: x.split("'")).apply(clean_height)
df["Weight"]=df["Weight"].apply(lambda x: x.split('k')[0])
df["Weight"]=df["Weight"].apply(lambda x: x.split('l')[0]).apply(lambda x: int(x))

# %%
df.Value.unique()
# Out:
# <StringArray>
# ['€103.5M',    '€63M',   '€120M',   '€129M',   '€132M',   '€111M', '€120.5M',
#    '€102M', '€185.5M',   '€110M',
#  ...
#     '€50K',    '€70K',    '€45K',    '€35K',    '€40K',    '€25K',    '€20K',
#     '€15K',    '€30K',     '€9K']
# Length: 255, dtype: str

# %%
def changek(x):
    try:
        if "M" in x:
            s=x.rstrip("M")
            return float(s) * 1000000.00
        elif "K" in x:
            s=x.rstrip("K")
            return float(s) *1000.00
        else:
            return float(x)
    except:
        return int(x)

# %%
df.Value=df.Value.apply(lambda x: x.lstrip("€")).apply(changek)
df.Wage=df.Wage.apply(lambda x: x.lstrip("€")).apply(changek)
df["Release Clause"]=df["Release Clause"].apply(lambda x: x.lstrip("€")).apply(changek)

# %%
df.Hits=df.Hits.fillna(0)

# %%
df.Hits=df.Hits.apply(changek)

# %% [markdown]
# #### Cleaning club name

# %%
df.Club=df.Club.apply(lambda x: x.lstrip("\r\n"))

# %%
df["W/F"]=df["W/F"].apply(lambda x: x.rstrip("★")).apply(lambda x: int(x))
df["SM"]=df["SM"].apply(lambda x: x.rstrip("★")).apply(lambda x: int(x))
df["IR"]=df["IR"].apply(lambda x: x.rstrip("★")).apply(lambda x: int(x))

# %% [markdown]
# #### changing joined to date time

# %%
df.Joined.unique()
# Out:
# <StringArray>
# [ 'Jul 1, 2004', 'Jul 10, 2018', 'Jul 16, 2014', 'Aug 30, 2015',
#   'Aug 3, 2017',  'Jul 1, 2014',  'Jul 1, 2017', 'Jul 19, 2018',
#   'Jul 1, 2018',  'Jan 1, 2018',
#  ...
#  'Oct 12, 2019', 'Mar 23, 2019', 'Mar 25, 2020',  'May 2, 2019',
#   'Jun 8, 2019', 'Dec 19, 2019',  'May 2, 2020', 'Sep 22, 2018',
#  'Feb 28, 2015',  'Mar 6, 2018']
# Length: 1869, dtype: str

# %%
def clean_datetime(x):
    months={"Jan":1,"Feb":2,"Mar":3,"Apr":4,"May":5,"Jun":6,"Jul":7,"Aug":8,"Sep":9,"Oct":10,"Nov":11,"Dec":12}
    year=x.split(" ")[-1]
    date=x.split(" ")[1].rstrip(",")
    month=x.split()[0]
    for i in months:
        if i==month:
            month=months[i]
    return (f"{date},{month},{year}")

# %%
df.Joined=df.Joined.apply(clean_datetime).apply(lambda x: x.replace(",","-"))

# %%
df.Joined=pd.to_datetime(df.Joined, format='%d-%m-%Y')

# %%
df.Joined
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2014-07-16
# 3       2015-08-30
# 4       2017-08-03
#            ...
# 18974   2018-07-13
# 18975   2020-08-01
# 18976   2019-03-08
# 18977   2020-09-22
# 18978   2019-07-29
# Name: Joined, Length: 18979, dtype: datetime64[us]

# %% [markdown]
# #### checking for duplicated rows

# %%
num_cols=df.select_dtypes(include=[np.number])
cat_cols=df.select_dtypes("object")
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_9564\3702246818.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols=df.select_dtypes("object")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
num_cols.columns
# Out:
# Index(['ID', 'Age', 'OVA', 'POT', 'Height', 'Weight', 'Value', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF',
#        'PHY', 'Hits'],
#       dtype='str')

# %%
df.describe().T
# Out:
#           count           mean    min       25%       50%       75%       max  \
# ID      18979.0  226403.384794   41.0  210135.0  232418.0  246922.5  259216.0
# Age     18979.0      25.194109   16.0      21.0      25.0      29.0      53.0
# OVA     18979.0      65.718636   47.0      61.0      66.0      70.0      93.0
# POT     18979.0      71.136414   47.0      67.0      71.0      75.0      95.0
# Height  18979.0      181.19922  155.0     176.0     181.0     186.0     206.0
# ...         ...            ...    ...       ...       ...       ...       ...
# PAS     18979.0      57.681016   25.0      51.0      58.0      64.0      93.0
# DRI     18979.0       62.87502   25.0      57.0      64.0      69.0      95.0
# DEF     18979.0      49.866221   12.0      35.0      53.0      63.0      91.0
# PHY     18979.0      64.368934   28.0      58.0      65.0      71.0      91.0
# Hits    18979.0       22.93672    0.0       1.0       4.0      12.0    8400.0
#
#                  std
# ...

# %%
num_key = ["Age", "OVA", "POT", "Value", "Wage", "Release Clause"]
fig, axes = plt.subplots(2, 3, figsize=(16, 8))
for ax, col in zip(axes.flat, num_key):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(col)
plt.tight_layout()

# %% [markdown]
# so the target feature value is heavily right skewwed so we will make the log of it

# %%
df["Value_log"]=np.log1p(df.Value)
df["ReleaseClause_log"]=np.log1p(df["Release Clause"])
df["Wage_log"]=np.log1p(df.Wage)

# %%
imp_attribute=["Age","OVA","POT","Value_log","Wage_log","ReleaseClause_log"]
sns.pairplot(df[imp_attribute])
plt.tight_layout()

# %% [markdown]
# this graph shows us many relationship between features such as it shows that release clause have a linear relationship with value and ova which is intresting. value and potentila could also be correlated.

# %%
sns.scatterplot(data=df,x="Age",y="OVA",hue="Value_log").set_title("Age vs OVA by value_log")
# Out:
# Text(0.5, 1.0, 'Age vs OVA by value_log')

# %%
sns.lineplot(data=df,x="Age",y="OVA").set_title("Age vs OVA by time")
# Out:
# Text(0.5, 1.0, 'Age vs OVA by time')

# %% [markdown]
# this graph shows that the peak of any footballer comes at the age of 29-35 where they have the peak ova and after that the ova tends to decrease at a faster rate

# %%
sns.histplot(x=df.OVA,hue=df.Age,palette="viridis").set_title("OVA distribution by age")
# Out:
# Text(0.5, 1.0, 'OVA distribution by age')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x="OVA",y="Value_log",hue="Age").set_title("Value vs OVA by age plus pot reg line")
sns.lineplot(x=df.POT,y=df.Value_log)
# Out:
# <Axes: title={'center': 'Value vs OVA by age plus pot reg line'}, xlabel='OVA', ylabel='Value_log'>

# %% [markdown]
# potential is linear to ova and value

# %%
sns.scatterplot(x=df.Value,y=df["ReleaseClause_log"],hue=df.OVA,palette="magma").set_title("release clause vs value by ova")
# Out:
# Text(0.5, 1.0, 'release clause vs value by ova')

# %% [markdown]
# for some player the release clause is zero as its optional and depend on club or player to decide.
# Release clause is high value than the marget value of the same player with same ova

# %%
cat_cols.columns
# Out:
# Index(['Name', 'Nationality', 'Club', 'Contract', 'Preferred Foot',
#        'Best Position', 'A/W', 'D/W'],
#       dtype='str')

# %%
for col in cat_cols.columns:
    print(col, "->", df[col].nunique(), "unique values")
# Out:
# Name -> 17920 unique values
# Nationality -> 164 unique values
# Club -> 682 unique values
# Contract -> 131 unique values
# Preferred Foot -> 2 unique values
# Best Position -> 15 unique values
# A/W -> 3 unique values
# D/W -> 3 unique values

# %%
low_card_cols = ["Preferred Foot", "Best Position", "A/W", "D/W"]

for col in low_card_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)

# %%
sns.barplot(data=df,x="Preferred Foot",y="Value_log")
# Out:
# <Axes: xlabel='Preferred Foot', ylabel='Value_log'>

# %% [markdown]
# as we can see foot doesnot matter in player value

# %%
top_n = 15

plt.figure(figsize=(10, 6))
df.Nationality.value_counts().head(top_n).plot(kind="barh")
plt.title(f"Top {top_n} nationalities by player count")
plt.xlabel("Number of players")
plt.gca().invert_yaxis()

# %%
plt.figure(figsize=(10, 6))
df.Club.value_counts().head(top_n).plot(kind="barh")
plt.title(f"Top {top_n} clubs by squad size in dataset")
plt.gca().invert_yaxis()

# %%
plt.figure(figsize=(14, 6))
order = df.groupby("Best Position")["Value_log"].median().sort_values(ascending=False).index
sns.boxplot(data=df, x="Best Position", y="Value_log", order=order)
plt.xticks(rotation=45)
plt.title("Value distribution by Best Position (sorted by median)")
# Out:
# Text(0.5, 1.0, 'Value distribution by Best Position (sorted by median)')

# %% [markdown]
# we can see that the attacking positions has high value compare to other positions

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x="Preferred Foot", y="Value_log")
plt.title("Value distribution by Preferred Foot")
# Out:
# Text(0.5, 1.0, 'Value distribution by Preferred Foot')

# %%
df.groupby("Best Position")["Value"].agg(["count", "mean", "median", "max"]).sort_values("mean", ascending=False)
# Out:
#                count          mean     median          max
# Best Position
# CF                78  6.913910e+06  1750000.0   83500000.0
# LW               186  5.443952e+06  1300000.0  132000000.0
# CM              1047  4.320606e+06  1300000.0   87500000.0
# RW               298  4.067181e+06  1200000.0  120500000.0
# CAM             2299  3.681720e+06  1100000.0  129000000.0
# LM               871  3.023088e+06  1200000.0   85000000.0
# CDM             1445  3.022806e+06  1100000.0  103000000.0
# LWB              261  2.934559e+06  1300000.0   56000000.0
# RWB              277  2.832563e+06  1300000.0   43500000.0
# ST              2680  2.805450e+06   950000.0  185500000.0
# LB              1086  2.648200e+06  1000000.0   90500000.0
# RB              1079  2.636766e+06  1100000.0  114000000.0
# CB              3686  2.351963e+06   850000.0  113000000.0
# RM              1611  2.340422e+06   975000.0   86500000.0
# GK              2075  2.117214e+06   525000.0  120000000.0

# %%
corr=df[["OVA","Value","POT","Age","Release Clause"]].corr()
sns.heatmap(data=corr,cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
df[["OVA","Value","POT","Age","Release Clause"]].describe()
# Out:
#                 OVA         Value           POT           Age  Release Clause
# count  18979.000000  1.897900e+04  18979.000000  18979.000000    1.897900e+04
# mean      65.718636  2.865063e+06     71.136414     25.194109    3.962951e+06
# std        6.968999  7.685154e+06      6.114635      4.710520    9.772762e+06
# min       47.000000  0.000000e+00     47.000000     16.000000    0.000000e+00
# 25%       61.000000  4.750000e+05     67.000000     21.000000    4.235000e+05
# 50%       66.000000  9.500000e+05     71.000000     25.000000    1.000000e+06
# 75%       70.000000  2.000000e+06     75.000000     29.000000    2.800000e+06
# max       93.000000  1.855000e+08     95.000000     53.000000    2.031000e+08

# %%
def_attribute=["Sprint Speed","Reactions","Mentality","Interceptions","Aggression","Marking","Standing Tackle","Sliding Tackle"]
for col in def_attribute:
    plt.figure(figsize=(12,4))
    sns.regplot(data=df,y=col,x="Defending",line_kws={"color": "red"})
    plt.title(f"{col} vs Defending")

# %% [markdown]
# only strong defensive attributes like sliding tackle,standing tackle, marking and interception show linear relationship other show some llinar features but filled with noise for example mentallity

# %%
att_attribute=["Finishing","Heading Accuracy","Volleys","Dribbling","Ball Control","Sprint Speed","Power","Stamina","SM","PHY"]
for col in att_attribute:
    plt.figure(figsize=(12,4))
    sns.regplot(data=df,x=col,y="Attacking",line_kws={"color": "red"})
    plt.title(f"{col} vs Attacking")

# %% [markdown]
# except sm and phy all other attributes show somewhat linear relationship  with attacking

# %%
gk_attributes=[ 'GK Diving', 'GK Handling',
       'GK Kicking', 'GK Positioning', 'GK Reflexes']
for col in gk_attributes:
    plt.figure(figsize=(12,4))
    sns.regplot(data=df,x=col,y="Goalkeeping",line_kws={"color": "red"})
    plt.title(f"{col} vs Goalkeeping")

# %% [markdown]
# all goalkeeping attriburtes have a linear relationship with goalkeeping.

# %% [markdown]
# ### by all the analysis we get that the value of a player is dependent on features such as age,ova,potential,release clause,position,Club

# %%
df_final=df[["Age","OVA","POT","Release Clause","Best Position","Club","Value","Attacking","Defending","Goalkeeping"]]

# %%
df_final.to_csv(r"D:\eda\data\data.csv",index=False)
